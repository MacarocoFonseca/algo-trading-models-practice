# %%
import yfinance as yf
import talib as ta
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
tesla_data = yf.download('TSLA', '2019-03-19', '2021-02-10')
tesla_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-19   17.833332   18.219999   17.563999   17.831333   17.831333
# 2019-03-20   17.979334   18.331333   17.753332   18.240000   18.240000
# 2019-03-21   18.173332   18.430000   17.896667   18.268000   18.268000
# 2019-03-22   18.172001   18.186666   17.600000   17.635332   17.635332
# 2019-03-25   17.313999   17.545334   16.964001   17.361334   17.361334
# ...                ...         ...         ...         ...         ...
# 2021-02-03  292.339996  292.693329  284.353333  284.896667  284.896667
# 2021-02-04  285.000000  285.500000  277.806671  283.329987  283.329987
# 2021-02-05  281.666656  288.256653  279.656677  284.076660  284.076660
# 2021-02-08  289.890015  292.589996  284.916656  287.806671  287.806671
# 2021-02-09  285.040009  286.600006  280.583344  283.153320  283.153320
#
#                Volume
# Date
# ...

# %%
tesla_data['SMA'] = ta.SMA(tesla_data['Adj Close'], 14)
tesla_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-19   17.833332   18.219999   17.563999   17.831333   17.831333
# 2019-03-20   17.979334   18.331333   17.753332   18.240000   18.240000
# 2019-03-21   18.173332   18.430000   17.896667   18.268000   18.268000
# 2019-03-22   18.172001   18.186666   17.600000   17.635332   17.635332
# 2019-03-25   17.313999   17.545334   16.964001   17.361334   17.361334
# ...                ...         ...         ...         ...         ...
# 2021-02-03  292.339996  292.693329  284.353333  284.896667  284.896667
# 2021-02-04  285.000000  285.500000  277.806671  283.329987  283.329987
# 2021-02-05  281.666656  288.256653  279.656677  284.076660  284.076660
# 2021-02-08  289.890015  292.589996  284.916656  287.806671  287.806671
# 2021-02-09  285.040009  286.600006  280.583344  283.153320  283.153320
#
#                Volume         SMA
# Date
# 2019-03-19  177009000         NaN
# ...

# %%
tesla_data['SMA'] = pd.to_datetime(tesla_data['SMA'])
tesla_data.index = tesla_data.index.tz_localize('UTC')

# %%
tesla_data['SMA'].plot()
plt.show()

# %%
df_tesla = pd.DataFrame(tesla_data)

# Convert the index to datetime
df_tesla.index = pd.to_datetime(df_tesla.index)
df_tesla
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-19 00:00:00+00:00   17.833332   18.219999   17.563999   17.831333
# 2019-03-20 00:00:00+00:00   17.979334   18.331333   17.753332   18.240000
# 2019-03-21 00:00:00+00:00   18.173332   18.430000   17.896667   18.268000
# 2019-03-22 00:00:00+00:00   18.172001   18.186666   17.600000   17.635332
# 2019-03-25 00:00:00+00:00   17.313999   17.545334   16.964001   17.361334
# ...                               ...         ...         ...         ...
# 2021-02-03 00:00:00+00:00  292.339996  292.693329  284.353333  284.896667
# 2021-02-04 00:00:00+00:00  285.000000  285.500000  277.806671  283.329987
# 2021-02-05 00:00:00+00:00  281.666656  288.256653  279.656677  284.076660
# 2021-02-08 00:00:00+00:00  289.890015  292.589996  284.916656  287.806671
# 2021-02-09 00:00:00+00:00  285.040009  286.600006  280.583344  283.153320
#
# ...

# %% [markdown]
# # Line Graph of close price

# %%
# Set the plot style
plt.style.use('seaborn-darkgrid')

# Plotting the close price column
df_tesla['Close'].plot(figsize=(10, 7), color='green')
# Setting the graph title
plt.title("Closing Price of Tesla", fontsize=14)
# Setting the x-axis title
plt.xlabel('Year-Month', fontsize=12)
# Setting the y-axis title
plt.ylabel('Price ($)', fontsize=12)
# Function for showing graph
plt.show()
# Out:
# /var/folders/y1/h3rdxlrj2qvdwwjh6r3b721m0000gp/T/ipykernel_8929/1933769553.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ## Scatter Plot of Two Stocks' Close Price
#
# Scatter plot is used to study the relationship between two variables. To plot the scatter plot of two columns in a dataframe, you will use the `scatter` method of `matplotlib`. The syntax is shown below:
#
# Syntax:
# ```python
# import matplotlib.pyplot as plt
# plt.scatter(col1, col2)
# ```
# 1. **col1**: First column (x-axis)
# 2. **col2**: Second column (y-axis)

# %%
# Fetch the JP Morgan price data
data = yf.download('jpm', start='2019-03-19', end='2021-02-10')

# Display the data
df_jpm = pd.DataFrame(data)
df_jpm
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-19  108.199997  108.400002  106.550003  106.800003   93.838615
# 2019-03-20  106.430000  106.650002  104.410004  104.519997   91.835327
# 2019-03-21  103.489998  103.489998  102.279999  102.870003   90.385574
# 2019-03-22  101.820000  102.320000   99.519997   99.760002   87.653000
# 2019-03-25   99.589996  100.570000   98.089996   98.930000   86.923737
# ...                ...         ...         ...         ...         ...
# 2021-02-03  133.649994  135.759995  133.509995  135.139999  126.777428
# 2021-02-04  135.470001  138.660004  135.470001  138.250000  129.694946
# 2021-02-05  139.389999  139.490005  137.380005  137.979996  129.441666
# 2021-02-08  138.199997  140.300003  138.179993  140.139999  131.468018
# 2021-02-09  139.429993  139.979996  138.539993  139.580002  130.942673
#
#               Volume
# Date
# ...

# %%
# Plot of Telsa vs JPM
plt.figure(figsize=(10,7))
plt.scatter(df_tesla['Close'], df_jpm['Close'])

# Set the title of the plot
plt.title('Telsa Price Vs. JPM Price', fontsize=14)
# Setting the x-axis title
plt.xlabel('Telsa Price', fontsize=12)
# Setting the y-axis title
plt.ylabel('JPM Price', fontsize=12)
# Function for showing graph
plt.show()

# %% [markdown]
# <a id='daily-returns'></a>
# ## Histogram of Daily Returns
#
# To plot the histogram of a column in a dataframe, you will use the `plot` method of `pandas`. The syntax is shown below:
#
# Syntax:
# ```python
# DataFrame[col].plot(kind='hist')
# ```
# 1. **col**: Column name
# 2. **kind**: Kind of plot (in case of histogram, it is `'hist'`)

# %%
# Histogram of daily returns
plt.figure(figsize=(10,7))
df_jpm['Close'].plot(kind='hist')

# Set the title of the plot
plt.title('close of JPM', fontsize=14)
# Setting the x-axis title
plt.xlabel('Returns', fontsize=12)
# Setting the y-axis title
plt.ylabel('Frequency', fontsize=12)
# Function for showing graph
plt.show()

# %%
# Data to be stored in the dataframe
stocks_info = [['FB', 50, 330], ['AMZN', 10, 3200], [
    'AAPL', 80, 120], ['NFLX', 40, 500], ['GOOG', 20, 2300]]

# Create a dataframe
stock_data = pd.DataFrame(stocks_info, columns=[
                          'ticker', 'quantity', 'price'], index=['S1', 'S2', 'S3', 'S4', 'S5'])

# Calculate the dollar value
stock_data['dollar_value'] = stock_data['quantity'] * stock_data['price']

# Plot the bar graph
plt.bar(stock_data['ticker'],stock_data['dollar_value'])

# Set title and axes labels
plt.xlabel('Ticker')
plt.ylabel('Dollar Value')
plt.title('Dollar Value of Tickers')
plt.show()

# %%
# Out:
# /var/folders/y1/h3rdxlrj2qvdwwjh6r3b721m0000gp/T/ipykernel_4259/1409731986.py:2: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
